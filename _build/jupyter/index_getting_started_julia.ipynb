# %% [markdown]
# <a id='learning-julia'></a>
# <ul class="badges">
#         <li><a href="#"><img src="/_static/img/jupyter-notebook-download-blue.svg" id="notebook_download_badge"></a></li>
#         <li><a href="#"><img src="/_static/img/pdf-download-blue.svg" id="pdf_download_badge"></a></li>
#         <li><a href="/status.html"><img src="https://img.shields.io/badge/Execution%20test-not%20available-lightgrey.svg" id="executability_status_badge"></a></li>
# </ul>
#
# <script>
# var path = window.location.pathname;
# var pageName = path.split("/").pop().split(".")[0];
# var notebookDownloadLink = ["/", "_downloads/ipynb/jl/", pageName, ".ipynb"].join("");
# document.getElementById('notebook_download_badge').parentElement.setAttribute('href', notebookDownloadLink);
# var pdfDownloadLink = ["/", "_downloads/pdf/jl/", pageName, ".pdf"].join("");
# document.getElementById('pdf_download_badge').parentElement.setAttribute('href', pdfDownloadLink);
# </script>
#
# <a href="/status.html"><img src="https://img.shields.io/badge/Execution%20test-not%20available-lightgrey.svg" id="executability_status_badge"></a>
#
# <div class="how-to">
#         <a href="#" class="toggle"><span class="icon icon-angle-double-down"></span>How to read this lecture...</a>
#         <div class="how-to-content">
#                 <p>Code should execute sequentially if run in a Jupyter notebook</p>
#                 <ul>
#                         <li>See the <a href="/jl/getting_started.html">set up page</a> to install Jupyter, Julia (1.0+) and all necessary libraries</li>
#                         <li>Please direct feedback to <a href="mailto:contact@quantecon.org">contact@quantecon.org</a> or the <a href="http://discourse.quantecon.org/">discourse forum</a></li>
#                         <li>For some notebooks, enable content with "Trust" on the command tab of Jupyter lab</li>
#                         <li>If using QuantEcon lectures for the first time on a computer, execute <tt>] add InstantiateFromURL</tt> inside of a notebook or the REPL</li>
#                 </ul>
#         </div>
# </div>

# %% [markdown]
# # Getting Started with Julia
#
# This first part of the course provides a relatively fast-paced introduction to enough of the Julia programming language to understand the lectures

# %% [markdown]
# ## Lectures
#
# - [Setting up Your Julia Environment](https://lectures.quantecon.org/jl/getting_started.html)
#   - [Overview](https://lectures.quantecon.org/jl/getting_started.html#overview)
#   - [A Note on Jupyter](https://lectures.quantecon.org/jl/getting_started.html#a-note-on-jupyter)
#   - [Desktop Installation of Julia and Jupyter](https://lectures.quantecon.org/jl/getting_started.html#desktop-installation-of-julia-and-jupyter)
#   - [Using Julia on the Web](https://lectures.quantecon.org/jl/getting_started.html#using-julia-on-the-web)
# - [Interacting with Julia](https://lectures.quantecon.org/jl/julia_environment.html)
#   - [Overview](https://lectures.quantecon.org/jl/julia_environment.html#overview)
#   - [Using Jupyter](https://lectures.quantecon.org/jl/julia_environment.html#using-jupyter)
#   - [Using the REPL](https://lectures.quantecon.org/jl/julia_environment.html#using-the-repl)
# - [Introductory Examples](https://lectures.quantecon.org/jl/julia_by_example.html)
#   - [Overview](https://lectures.quantecon.org/jl/julia_by_example.html#overview)
#   - [Example: Plotting a White Noise Process](https://lectures.quantecon.org/jl/julia_by_example.html#example-plotting-a-white-noise-process)
#   - [Example: Variations on Fixed Points](https://lectures.quantecon.org/jl/julia_by_example.html#example-variations-on-fixed-points)
#   - [Exercises](https://lectures.quantecon.org/jl/julia_by_example.html#exercises)
#   - [Solutions](https://lectures.quantecon.org/jl/julia_by_example.html#solutions)
# - [Julia Essentials](https://lectures.quantecon.org/jl/julia_essentials.html)
#   - [Overview](https://lectures.quantecon.org/jl/julia_essentials.html#overview)
#   - [Common Data Types](https://lectures.quantecon.org/jl/julia_essentials.html#common-data-types)
#   - [Iterating](https://lectures.quantecon.org/jl/julia_essentials.html#iterating)
#   - [Comparisons and Logical Operators](https://lectures.quantecon.org/jl/julia_essentials.html#comparisons-and-logical-operators)
#   - [User-Defined Functions](https://lectures.quantecon.org/jl/julia_essentials.html#user-defined-functions)
#   - [Broadcasting](https://lectures.quantecon.org/jl/julia_essentials.html#broadcasting)
#   - [Scoping and Closures](https://lectures.quantecon.org/jl/julia_essentials.html#scoping-and-closures)
#   - [Exercises](https://lectures.quantecon.org/jl/julia_essentials.html#exercises)
#   - [Solutions](https://lectures.quantecon.org/jl/julia_essentials.html#solutions)
# - [Arrays, Tuples, Ranges, and Other Fundamental Types](https://lectures.quantecon.org/jl/fundamental_types.html)
#   - [Overview](https://lectures.quantecon.org/jl/fundamental_types.html#overview)
#   - [Array Basics](https://lectures.quantecon.org/jl/fundamental_types.html#array-basics)
#   - [Operations on Arrays](https://lectures.quantecon.org/jl/fundamental_types.html#operations-on-arrays)
#   - [Ranges](https://lectures.quantecon.org/jl/fundamental_types.html#ranges)
#   - [Tuples and Named Tuples](https://lectures.quantecon.org/jl/fundamental_types.html#tuples-and-named-tuples)
#   - [Nothing, Missing, and Unions](https://lectures.quantecon.org/jl/fundamental_types.html#nothing-missing-and-unions)
#   - [Exercises](https://lectures.quantecon.org/jl/fundamental_types.html#exercises)
#   - [Solutions](https://lectures.quantecon.org/jl/fundamental_types.html#solutions)
# - [Introduction to Types and Generic Programming](https://lectures.quantecon.org/jl/introduction_to_types.html)
#   - [Overview](https://lectures.quantecon.org/jl/introduction_to_types.html#overview)
#   - [Finding and Interpreting Types](https://lectures.quantecon.org/jl/introduction_to_types.html#finding-and-interpreting-types)
#   - [The Type Hierarchy](https://lectures.quantecon.org/jl/introduction_to_types.html#the-type-hierarchy)
#   - [Deducing and Declaring Types](https://lectures.quantecon.org/jl/introduction_to_types.html#deducing-and-declaring-types)
#   - [Creating New Types](https://lectures.quantecon.org/jl/introduction_to_types.html#creating-new-types)
#   - [Introduction to Multiple Dispatch](https://lectures.quantecon.org/jl/introduction_to_types.html#introduction-to-multiple-dispatch)
#   - [Exercises](https://lectures.quantecon.org/jl/introduction_to_types.html#exercises)
