# %% [markdown]
# <a id='single-agent-models'></a>
# <ul class="badges">
#         <li><a href="#"><img src="/_static/img/jupyter-notebook-download-blue.svg" id="notebook_download_badge"></a></li>
#         <li><a href="#"><img src="/_static/img/pdf-download-blue.svg" id="pdf_download_badge"></a></li>
#         <li><a href="/status.html"><img src="https://img.shields.io/badge/Execution%20test-not%20available-lightgrey.svg" id="executability_status_badge"></a></li>
# </ul>
#
# <script>
# var path = window.location.pathname;
# var pageName = path.split("/").pop().split(".")[0];
# var notebookDownloadLink = ["/", "_downloads/ipynb/jl/", pageName, ".ipynb"].join("");
# document.getElementById('notebook_download_badge').parentElement.setAttribute('href', notebookDownloadLink);
# var pdfDownloadLink = ["/", "_downloads/pdf/jl/", pageName, ".pdf"].join("");
# document.getElementById('pdf_download_badge').parentElement.setAttribute('href', pdfDownloadLink);
# </script>
#
# <a href="/status.html"><img src="https://img.shields.io/badge/Execution%20test-not%20available-lightgrey.svg" id="executability_status_badge"></a>
#
# <div class="how-to">
#         <a href="#" class="toggle"><span class="icon icon-angle-double-down"></span>How to read this lecture...</a>
#         <div class="how-to-content">
#                 <p>Code should execute sequentially if run in a Jupyter notebook</p>
#                 <ul>
#                         <li>See the <a href="/jl/getting_started.html">set up page</a> to install Jupyter, Julia (1.0+) and all necessary libraries</li>
#                         <li>Please direct feedback to <a href="mailto:contact@quantecon.org">contact@quantecon.org</a> or the <a href="http://discourse.quantecon.org/">discourse forum</a></li>
#                         <li>For some notebooks, enable content with "Trust" on the command tab of Jupyter lab</li>
#                         <li>If using QuantEcon lectures for the first time on a computer, execute <tt>] add InstantiateFromURL</tt> inside of a notebook or the REPL</li>
#                 </ul>
#         </div>
# </div>

# %% [markdown]
# # Dynamic Programming
#
# This section of the course contains foundational models for dynamic economic
# modeling.   Most are single agent problems that take the activities of other
# agents as given.  Later we will look at full equilibrium problems.

# %% [markdown]
# ## Lectures
#
# - [Shortest Paths](https://lectures.quantecon.org/jl/short_path.html)
#   - [Overview](https://lectures.quantecon.org/jl/short_path.html#overview)
#   - [Outline of the Problem](https://lectures.quantecon.org/jl/short_path.html#outline-of-the-problem)
#   - [Finding Least-Cost Paths](https://lectures.quantecon.org/jl/short_path.html#finding-least-cost-paths)
#   - [Solving for $ J $](https://lectures.quantecon.org/jl/short_path.html#solving-for)
#   - [Exercises](https://lectures.quantecon.org/jl/short_path.html#exercises)
#   - [Solutions](https://lectures.quantecon.org/jl/short_path.html#solutions)
# - [Job Search I: The McCall Search Model](https://lectures.quantecon.org/jl/mccall_model.html)
#   - [Overview](https://lectures.quantecon.org/jl/mccall_model.html#overview)
#   - [The McCall Model](https://lectures.quantecon.org/jl/mccall_model.html#the-mccall-model)
#   - [Computing the Optimal Policy: Take 1](https://lectures.quantecon.org/jl/mccall_model.html#computing-the-optimal-policy-take-1)
#   - [Computing the Optimal Policy: Take 2](https://lectures.quantecon.org/jl/mccall_model.html#computing-the-optimal-policy-take-2)
#   - [Exercises](https://lectures.quantecon.org/jl/mccall_model.html#exercises)
#   - [Solutions](https://lectures.quantecon.org/jl/mccall_model.html#solutions)
# - [Job Search II: Search and Separation](https://lectures.quantecon.org/jl/mccall_model_with_separation.html)
#   - [Overview](https://lectures.quantecon.org/jl/mccall_model_with_separation.html#overview)
#   - [The Model](https://lectures.quantecon.org/jl/mccall_model_with_separation.html#the-model)
#   - [Solving the Model using Dynamic Programming](https://lectures.quantecon.org/jl/mccall_model_with_separation.html#solving-the-model-using-dynamic-programming)
#   - [Implementation](https://lectures.quantecon.org/jl/mccall_model_with_separation.html#implementation)
#   - [The Reservation Wage](https://lectures.quantecon.org/jl/mccall_model_with_separation.html#the-reservation-wage)
#   - [Exercises](https://lectures.quantecon.org/jl/mccall_model_with_separation.html#exercises)
#   - [Solutions](https://lectures.quantecon.org/jl/mccall_model_with_separation.html#solutions)
# - [A Problem that Stumped Milton Friedman](https://lectures.quantecon.org/jl/wald_friedman.html)
#   - [Overview](https://lectures.quantecon.org/jl/wald_friedman.html#overview)
#   - [Origin of the problem](https://lectures.quantecon.org/jl/wald_friedman.html#origin-of-the-problem)
#   - [A dynamic programming approach](https://lectures.quantecon.org/jl/wald_friedman.html#a-dynamic-programming-approach)
#   - [Implementation](https://lectures.quantecon.org/jl/wald_friedman.html#implementation)
#   - [Comparison with Neyman-Pearson formulation](https://lectures.quantecon.org/jl/wald_friedman.html#comparison-with-neyman-pearson-formulation)
# - [Job Search III: Search with Learning](https://lectures.quantecon.org/jl/odu.html)
#   - [Overview](https://lectures.quantecon.org/jl/odu.html#overview)
#   - [Model](https://lectures.quantecon.org/jl/odu.html#model)
#   - [Take 1: Solution by VFI](https://lectures.quantecon.org/jl/odu.html#take-1-solution-by-vfi)
#   - [Take 2: A More Efficient Method](https://lectures.quantecon.org/jl/odu.html#take-2-a-more-efficient-method)
#   - [Exercises](https://lectures.quantecon.org/jl/odu.html#exercises)
#   - [Solutions](https://lectures.quantecon.org/jl/odu.html#solutions)
# - [Job Search IV: Modeling Career Choice](https://lectures.quantecon.org/jl/career.html)
#   - [Overview](https://lectures.quantecon.org/jl/career.html#overview)
#   - [Model](https://lectures.quantecon.org/jl/career.html#model)
#   - [Exercises](https://lectures.quantecon.org/jl/career.html#exercises)
#   - [Solutions](https://lectures.quantecon.org/jl/career.html#solutions)
# - [Job Search V: On-the-Job Search](https://lectures.quantecon.org/jl/jv.html)
#   - [Overview](https://lectures.quantecon.org/jl/jv.html#overview)
#   - [Model](https://lectures.quantecon.org/jl/jv.html#model)
#   - [Implementation](https://lectures.quantecon.org/jl/jv.html#implementation)
#   - [Solving for Policies](https://lectures.quantecon.org/jl/jv.html#solving-for-policies)
#   - [Exercises](https://lectures.quantecon.org/jl/jv.html#exercises)
#   - [Solutions](https://lectures.quantecon.org/jl/jv.html#solutions)
# - [Optimal Growth I: The Stochastic Optimal Growth Model](https://lectures.quantecon.org/jl/optgrowth.html)
#   - [Overview](https://lectures.quantecon.org/jl/optgrowth.html#overview)
#   - [The Model](https://lectures.quantecon.org/jl/optgrowth.html#the-model)
#   - [Computation](https://lectures.quantecon.org/jl/optgrowth.html#computation)
#   - [Exercises](https://lectures.quantecon.org/jl/optgrowth.html#exercises)
#   - [Solutions](https://lectures.quantecon.org/jl/optgrowth.html#solutions)
# - [Optimal Growth II: Time Iteration](https://lectures.quantecon.org/jl/coleman_policy_iter.html)
#   - [Overview](https://lectures.quantecon.org/jl/coleman_policy_iter.html#overview)
#   - [The Euler Equation](https://lectures.quantecon.org/jl/coleman_policy_iter.html#the-euler-equation)
#   - [Comparison with Value Function Iteration](https://lectures.quantecon.org/jl/coleman_policy_iter.html#comparison-with-value-function-iteration)
#   - [Implementation](https://lectures.quantecon.org/jl/coleman_policy_iter.html#implementation)
#   - [Exercises](https://lectures.quantecon.org/jl/coleman_policy_iter.html#exercises)
#   - [Solutions](https://lectures.quantecon.org/jl/coleman_policy_iter.html#solutions)
# - [Optimal Growth III: The Endogenous Grid Method](https://lectures.quantecon.org/jl/egm_policy_iter.html)
#   - [Overview](https://lectures.quantecon.org/jl/egm_policy_iter.html#overview)
#   - [Key Idea](https://lectures.quantecon.org/jl/egm_policy_iter.html#key-idea)
#   - [Implementation](https://lectures.quantecon.org/jl/egm_policy_iter.html#implementation)
#   - [Speed](https://lectures.quantecon.org/jl/egm_policy_iter.html#speed)
# - [LQ Dynamic Programming Problems](https://lectures.quantecon.org/jl/lqcontrol.html)
#   - [Overview](https://lectures.quantecon.org/jl/lqcontrol.html#overview)
#   - [Introduction](https://lectures.quantecon.org/jl/lqcontrol.html#introduction)
#   - [Optimality – Finite Horizon](https://lectures.quantecon.org/jl/lqcontrol.html#optimality-finite-horizon)
#   - [Implementation](https://lectures.quantecon.org/jl/lqcontrol.html#implementation)
#   - [Extensions and Comments](https://lectures.quantecon.org/jl/lqcontrol.html#extensions-and-comments)
#   - [Further Applications](https://lectures.quantecon.org/jl/lqcontrol.html#further-applications)
#   - [Exercises](https://lectures.quantecon.org/jl/lqcontrol.html#exercises)
#   - [Solutions](https://lectures.quantecon.org/jl/lqcontrol.html#solutions)
# - [Optimal Savings I: The Permanent Income Model](https://lectures.quantecon.org/jl/perm_income.html)
#   - [Overview](https://lectures.quantecon.org/jl/perm_income.html#overview)
#   - [The Savings Problem](https://lectures.quantecon.org/jl/perm_income.html#the-savings-problem)
#   - [Alternative Representations](https://lectures.quantecon.org/jl/perm_income.html#alternative-representations)
#   - [Two Classic Examples](https://lectures.quantecon.org/jl/perm_income.html#two-classic-examples)
#   - [Further Reading](https://lectures.quantecon.org/jl/perm_income.html#further-reading)
#   - [Appendix: the Euler Equation](https://lectures.quantecon.org/jl/perm_income.html#appendix-the-euler-equation)
# - [Optimal Savings II: LQ Techniques](https://lectures.quantecon.org/jl/perm_income_cons.html)
#   - [Overview](https://lectures.quantecon.org/jl/perm_income_cons.html#overview)
#   - [Introduction](https://lectures.quantecon.org/jl/perm_income_cons.html#introduction)
#   - [The LQ Approach](https://lectures.quantecon.org/jl/perm_income_cons.html#the-lq-approach)
#   - [Implementation](https://lectures.quantecon.org/jl/perm_income_cons.html#implementation)
#   - [Two Example Economies](https://lectures.quantecon.org/jl/perm_income_cons.html#two-example-economies)
# - [Consumption and Tax Smoothing with Complete and Incomplete Markets](https://lectures.quantecon.org/jl/smoothing.html)
#   - [Overview](https://lectures.quantecon.org/jl/smoothing.html#overview)
#   - [Background](https://lectures.quantecon.org/jl/smoothing.html#background)
#   - [Model 1 (Complete Markets)](https://lectures.quantecon.org/jl/smoothing.html#model-1-complete-markets)
#   - [Model 2 (One-Period Risk Free Debt Only)](https://lectures.quantecon.org/jl/smoothing.html#model-2-one-period-risk-free-debt-only)
#   - [Example: Tax Smoothing with Complete Markets](https://lectures.quantecon.org/jl/smoothing.html#example-tax-smoothing-with-complete-markets)
#   - [Linear State Space Version of Complete Markets Model](https://lectures.quantecon.org/jl/smoothing.html#linear-state-space-version-of-complete-markets-model)
# - [Optimal Savings III: Occasionally Binding Constraints](https://lectures.quantecon.org/jl/ifp.html)
#   - [Overview](https://lectures.quantecon.org/jl/ifp.html#overview)
#   - [The Optimal Savings Problem](https://lectures.quantecon.org/jl/ifp.html#the-optimal-savings-problem)
#   - [Computation](https://lectures.quantecon.org/jl/ifp.html#computation)
#   - [Exercises](https://lectures.quantecon.org/jl/ifp.html#exercises)
#   - [Solutions](https://lectures.quantecon.org/jl/ifp.html#solutions)
# - [Robustness](https://lectures.quantecon.org/jl/robustness.html)
#   - [Overview](https://lectures.quantecon.org/jl/robustness.html#overview)
#   - [The Model](https://lectures.quantecon.org/jl/robustness.html#the-model)
#   - [Constructing More Robust Policies](https://lectures.quantecon.org/jl/robustness.html#constructing-more-robust-policies)
#   - [Robustness as Outcome of a Two-Person Zero-Sum Game](https://lectures.quantecon.org/jl/robustness.html#robustness-as-outcome-of-a-two-person-zero-sum-game)
#   - [The Stochastic Case](https://lectures.quantecon.org/jl/robustness.html#the-stochastic-case)
#   - [Implementation](https://lectures.quantecon.org/jl/robustness.html#implementation)
#   - [Application](https://lectures.quantecon.org/jl/robustness.html#application)
#   - [Appendix](https://lectures.quantecon.org/jl/robustness.html#appendix)
# - [Discrete State Dynamic Programming](https://lectures.quantecon.org/jl/discrete_dp.html)
#   - [Overview](https://lectures.quantecon.org/jl/discrete_dp.html#overview)
#   - [Discrete DPs](https://lectures.quantecon.org/jl/discrete_dp.html#discrete-dps)
#   - [Solving Discrete DPs](https://lectures.quantecon.org/jl/discrete_dp.html#solving-discrete-dps)
#   - [Example: A Growth Model](https://lectures.quantecon.org/jl/discrete_dp.html#example-a-growth-model)
#   - [Exercises](https://lectures.quantecon.org/jl/discrete_dp.html#exercises)
#   - [Solutions](https://lectures.quantecon.org/jl/discrete_dp.html#solutions)
#   - [Appendix: Algorithms](https://lectures.quantecon.org/jl/discrete_dp.html#appendix-algorithms)
