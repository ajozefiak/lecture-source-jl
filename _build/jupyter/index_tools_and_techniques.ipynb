# %% [markdown]
# <a id='tools-and-techniques'></a>
# <ul class="badges">
#         <li><a href="#"><img src="/_static/img/jupyter-notebook-download-blue.svg" id="notebook_download_badge"></a></li>
#         <li><a href="#"><img src="/_static/img/pdf-download-blue.svg" id="pdf_download_badge"></a></li>
#         <li><a href="/status.html"><img src="https://img.shields.io/badge/Execution%20test-not%20available-lightgrey.svg" id="executability_status_badge"></a></li>
# </ul>
#
# <script>
# var path = window.location.pathname;
# var pageName = path.split("/").pop().split(".")[0];
# var notebookDownloadLink = ["/", "_downloads/ipynb/jl/", pageName, ".ipynb"].join("");
# document.getElementById('notebook_download_badge').parentElement.setAttribute('href', notebookDownloadLink);
# var pdfDownloadLink = ["/", "_downloads/pdf/jl/", pageName, ".pdf"].join("");
# document.getElementById('pdf_download_badge').parentElement.setAttribute('href', pdfDownloadLink);
# </script>
#
# <a href="/status.html"><img src="https://img.shields.io/badge/Execution%20test-not%20available-lightgrey.svg" id="executability_status_badge"></a>
#
# <div class="how-to">
#         <a href="#" class="toggle"><span class="icon icon-angle-double-down"></span>How to read this lecture...</a>
#         <div class="how-to-content">
#                 <p>Code should execute sequentially if run in a Jupyter notebook</p>
#                 <ul>
#                         <li>See the <a href="/jl/getting_started.html">set up page</a> to install Jupyter, Julia (1.0+) and all necessary libraries</li>
#                         <li>Please direct feedback to <a href="mailto:contact@quantecon.org">contact@quantecon.org</a> or the <a href="http://discourse.quantecon.org/">discourse forum</a></li>
#                         <li>For some notebooks, enable content with "Trust" on the command tab of Jupyter lab</li>
#                         <li>If using QuantEcon lectures for the first time on a computer, execute <tt>] add InstantiateFromURL</tt> inside of a notebook or the REPL</li>
#                 </ul>
#         </div>
# </div>

# %% [markdown]
# # Tools and Techniques
#
# This section of the course contains foundational mathematical and statistical
# tools and techniques

# %% [markdown]
# ## Lectures
#
# - [Linear Algebra](https://lectures.quantecon.org/jl/linear_algebra.html)
#   - [Overview](https://lectures.quantecon.org/jl/linear_algebra.html#overview)
#   - [Vectors](https://lectures.quantecon.org/jl/linear_algebra.html#vectors)
#   - [Matrices](https://lectures.quantecon.org/jl/linear_algebra.html#matrices)
#   - [Solving Systems of Equations](https://lectures.quantecon.org/jl/linear_algebra.html#solving-systems-of-equations)
#   - [Eigenvalues and Eigenvectors](https://lectures.quantecon.org/jl/linear_algebra.html#eigenvalues-and-eigenvectors)
#   - [Further Topics](https://lectures.quantecon.org/jl/linear_algebra.html#further-topics)
#   - [Exercises](https://lectures.quantecon.org/jl/linear_algebra.html#exercises)
#   - [Solutions](https://lectures.quantecon.org/jl/linear_algebra.html#solutions)
# - [Orthogonal Projections and Their Applications](https://lectures.quantecon.org/jl/orth_proj.html)
#   - [Overview](https://lectures.quantecon.org/jl/orth_proj.html#overview)
#   - [Key Definitions](https://lectures.quantecon.org/jl/orth_proj.html#key-definitions)
#   - [The Orthogonal Projection Theorem](https://lectures.quantecon.org/jl/orth_proj.html#the-orthogonal-projection-theorem)
#   - [Orthonormal Basis](https://lectures.quantecon.org/jl/orth_proj.html#orthonormal-basis)
#   - [Projection Using Matrix Algebra](https://lectures.quantecon.org/jl/orth_proj.html#projection-using-matrix-algebra)
#   - [Least Squares Regression](https://lectures.quantecon.org/jl/orth_proj.html#least-squares-regression)
#   - [Orthogonalization and Decomposition](https://lectures.quantecon.org/jl/orth_proj.html#orthogonalization-and-decomposition)
#   - [Exercises](https://lectures.quantecon.org/jl/orth_proj.html#exercises)
#   - [Solutions](https://lectures.quantecon.org/jl/orth_proj.html#solutions)
# - [LLN and CLT](https://lectures.quantecon.org/jl/lln_clt.html)
#   - [Overview](https://lectures.quantecon.org/jl/lln_clt.html#overview)
#   - [Relationships](https://lectures.quantecon.org/jl/lln_clt.html#relationships)
#   - [LLN](https://lectures.quantecon.org/jl/lln_clt.html#lln)
#   - [CLT](https://lectures.quantecon.org/jl/lln_clt.html#clt)
#   - [Exercises](https://lectures.quantecon.org/jl/lln_clt.html#exercises)
#   - [Solutions](https://lectures.quantecon.org/jl/lln_clt.html#solutions)
# - [Linear State Space Models](https://lectures.quantecon.org/jl/linear_models.html)
#   - [Overview](https://lectures.quantecon.org/jl/linear_models.html#overview)
#   - [The Linear State Space Model](https://lectures.quantecon.org/jl/linear_models.html#the-linear-state-space-model)
#   - [Distributions and Moments](https://lectures.quantecon.org/jl/linear_models.html#distributions-and-moments)
#   - [Stationarity and Ergodicity](https://lectures.quantecon.org/jl/linear_models.html#stationarity-and-ergodicity)
#   - [Noisy Observations](https://lectures.quantecon.org/jl/linear_models.html#noisy-observations)
#   - [Prediction](https://lectures.quantecon.org/jl/linear_models.html#prediction)
#   - [Code](https://lectures.quantecon.org/jl/linear_models.html#code)
#   - [Exercises](https://lectures.quantecon.org/jl/linear_models.html#exercises)
#   - [Solutions](https://lectures.quantecon.org/jl/linear_models.html#solutions)
# - [Finite Markov Chains](https://lectures.quantecon.org/jl/finite_markov.html)
#   - [Overview](https://lectures.quantecon.org/jl/finite_markov.html#overview)
#   - [Definitions](https://lectures.quantecon.org/jl/finite_markov.html#definitions)
#   - [Simulation](https://lectures.quantecon.org/jl/finite_markov.html#simulation)
#   - [Marginal Distributions](https://lectures.quantecon.org/jl/finite_markov.html#marginal-distributions)
#   - [Irreducibility and Aperiodicity](https://lectures.quantecon.org/jl/finite_markov.html#irreducibility-and-aperiodicity)
#   - [Stationary Distributions](https://lectures.quantecon.org/jl/finite_markov.html#stationary-distributions)
#   - [Ergodicity](https://lectures.quantecon.org/jl/finite_markov.html#ergodicity)
#   - [Computing Expectations](https://lectures.quantecon.org/jl/finite_markov.html#computing-expectations)
#   - [Exercises](https://lectures.quantecon.org/jl/finite_markov.html#exercises)
#   - [Solutions](https://lectures.quantecon.org/jl/finite_markov.html#solutions)
# - [Continuous State Markov Chains](https://lectures.quantecon.org/jl/stationary_densities.html)
#   - [Overview](https://lectures.quantecon.org/jl/stationary_densities.html#overview)
#   - [The Density Case](https://lectures.quantecon.org/jl/stationary_densities.html#the-density-case)
#   - [Beyond Densities](https://lectures.quantecon.org/jl/stationary_densities.html#beyond-densities)
#   - [Stability](https://lectures.quantecon.org/jl/stationary_densities.html#stability)
#   - [Exercises](https://lectures.quantecon.org/jl/stationary_densities.html#exercises)
#   - [Solutions](https://lectures.quantecon.org/jl/stationary_densities.html#solutions)
#   - [Appendix](https://lectures.quantecon.org/jl/stationary_densities.html#appendix)
# - [A First Look at the Kalman Filter](https://lectures.quantecon.org/jl/kalman.html)
#   - [Overview](https://lectures.quantecon.org/jl/kalman.html#overview)
#   - [The Basic Idea](https://lectures.quantecon.org/jl/kalman.html#the-basic-idea)
#   - [Convergence](https://lectures.quantecon.org/jl/kalman.html#convergence)
#   - [Implementation](https://lectures.quantecon.org/jl/kalman.html#implementation)
#   - [Exercises](https://lectures.quantecon.org/jl/kalman.html#exercises)
#   - [Solutions](https://lectures.quantecon.org/jl/kalman.html#solutions)
